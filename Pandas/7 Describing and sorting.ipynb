# %%
import pandas as pd
df=pd.read_csv("../data/03-Pandas/tips.csv")

# %%
df.describe().transpose()
# Out:
#                   count          mean           std           min  \
# total_bill        244.0  1.978594e+01  8.902412e+00  3.070000e+00
# tip               244.0  2.998279e+00  1.383638e+00  1.000000e+00
# size              244.0  2.569672e+00  9.510998e-01  1.000000e+00
# price_per_person  244.0  7.888197e+00  2.914234e+00  2.880000e+00
# CC Number         244.0  2.563496e+15  2.369340e+15  6.040679e+10
#
#                            25%           50%           75%           max
# total_bill        1.334750e+01  1.779500e+01  2.412750e+01  5.081000e+01
# tip               2.000000e+00  2.900000e+00  3.562500e+00  1.000000e+01
# size              2.000000e+00  2.000000e+00  3.000000e+00  6.000000e+00
# price_per_person  5.800000e+00  7.255000e+00  9.390000e+00  2.027000e+01
# CC Number         3.040731e+13  3.525318e+15  4.553675e+15  6.596454e+15

# %%
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01  Female     No  Sun  Dinner     2              8.49
# 1       10.34  1.66    Male     No  Sun  Dinner     3              3.45
# 2       21.01  3.50    Male     No  Sun  Dinner     3              7.00
# 3       23.68  3.31    Male     No  Sun  Dinner     2             11.84
# 4       24.59  3.61  Female     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %%
sortedIndex=df["size"].sort_index(ascending=False)
sortedIndex
# Out:
# 243    2
# 242    2
# 241    2
# 240    2
# 239    3
#       ..
# 4      4
# 3      2
# 2      3
# 1      3
# 0      2
# Name: size, Length: 244, dtype: int64

# %%
df["size"].sort_values(ascending=False) # return only size
df.sort_values("tip",ascending=False)  #return entire df
# Out:
#      total_bill    tip sex smoker   day    time  size  price_per_person  \
# 170       50.81  10.00   M    Yes   Sat  Dinner     3             16.94
# 212       48.33   9.00   M     No   Sat  Dinner     4             12.08
# 23        39.42   7.58   M     No   Sat  Dinner     4              9.86
# 59        48.27   6.73   M     No   Sat  Dinner     4             12.07
# 141       34.30   6.70   M     No  Thur   Lunch     6              5.72
# ..          ...    ...  ..    ...   ...     ...   ...               ...
# 0         16.99   1.01   F     No   Sun  Dinner     2              8.49
# 236       12.60   1.00   M    Yes   Sat  Dinner     2              6.30
# 111        7.25   1.00   F     No   Sat  Dinner     1              7.25
# 67         3.07   1.00   F    Yes   Sat  Dinner     1              3.07
# 92         5.75   1.00   F    Yes   Fri  Dinner     2              2.88
#
#              Payer Name         CC Number Payment ID
# ...

# %%
#it will sort with tip first and if two tips are same then it will go with total_bill
df.sort_values(["tip","total_bill"],ascending=False)
# Out:
#      total_bill    tip     sex smoker   day    time  size  price_per_person  \
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3             16.94
# 212       48.33   9.00    Male     No   Sat  Dinner     4             12.08
# 23        39.42   7.58    Male     No   Sat  Dinner     4              9.86
# 59        48.27   6.73    Male     No   Sat  Dinner     4             12.07
# 141       34.30   6.70    Male     No  Thur   Lunch     6              5.72
# ..          ...    ...     ...    ...   ...     ...   ...               ...
# 0         16.99   1.01  Female     No   Sun  Dinner     2              8.49
# 236       12.60   1.00    Male    Yes   Sat  Dinner     2              6.30
# 111        7.25   1.00  Female     No   Sat  Dinner     1              7.25
# 92         5.75   1.00  Female    Yes   Fri  Dinner     2              2.88
# 67         3.07   1.00  Female    Yes   Sat  Dinner     1              3.07
#
#              Payer Name         CC Number Payment ID
# ...

# %%
df["tip"].max()
# Out:
# 10.0

# %%
#return index
df["tip"].idxmax()
# Out:
# 170

# %%
df.iloc[df["tip"].idxmax()]
# Out:
# total_bill                     50.81
# tip                             10.0
# sex                             Male
# smoker                           Yes
# day                              Sat
# time                          Dinner
# size                               3
# price_per_person               16.94
# Payer Name             Gregory Clark
# CC Number           5473850968388236
# Payment ID                   Sat1954
# Name: 170, dtype: object

# %%
df.corr()
# Out:
#                   total_bill       tip      size  price_per_person  CC Number
# total_bill          1.000000  0.675734  0.598315          0.647554   0.104576
# tip                 0.675734  1.000000  0.489299          0.347405   0.110857
# size                0.598315  0.489299  1.000000         -0.175359  -0.030239
# price_per_person    0.647554  0.347405 -0.175359          1.000000   0.135240
# CC Number           0.104576  0.110857 -0.030239          0.135240   1.000000

# %%
df["size"].value_counts()
# Out:
# 2    156
# 3     38
# 4     37
# 5      5
# 1      4
# 6      4
# Name: size, dtype: int64

# %%
df["size"].unique()
# Out:
# array([2, 3, 4, 1, 6, 5])

# %%
#len(df["size"].unique())
df["size"].nunique()
# Out:
# 6

# %%
df["size"].nunique()
# Out:
# 6

# %% [markdown]
# # replace

# %%
df["sex"]=df["sex"].replace("Male","M")

# %%
#dont use this when you want to replace multiple rows
df["sex"]=df["sex"].replace(["M","F"],["Male","Female"])

# %% [markdown]
# # Map

# %%
#use this for multiple values
df["sex"]=df["sex"].map({"Male":"M","Female":"F"})

# %%
df.head()
# Out:
#    total_bill   tip sex smoker  day    time  size  price_per_person  \
# 0       16.99  1.01   F     No  Sun  Dinner     2              8.49
# 1       10.34  1.66   M     No  Sun  Dinner     3              3.45
# 2       21.01  3.50   M     No  Sun  Dinner     3              7.00
# 3       23.68  3.31   M     No  Sun  Dinner     2             11.84
# 4       24.59  3.61   F     No  Sun  Dinner     4              6.15
#
#            Payer Name         CC Number Payment ID
# 0  Christy Cunningham  3560325168603410    Sun2959
# 1      Douglas Tucker  4478071379779230    Sun4608
# 2      Travis Walters  6011812112971322    Sun4458
# 3    Nathaniel Harris  4676137647685994    Sun5260
# 4        Tonya Carter  4832732618637221    Sun2251

# %% [markdown]
# # Duplicated

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 239    False
# 240    False
# 241    False
# 242    False
# 243    False
# Length: 244, dtype: bool

# %% [markdown]
# df2=pd.DataFrame([1,2,3,2],["a","b","c","d"])
# df2

# %%
df2.duplicated()
# Out:
# a    False
# b    False
# c    False
# d     True
# dtype: bool

# %%
#drop dublicated
df2.drop_duplicates()
# Out:
#    0
# a  1
# b  2
# c  3

# %% [markdown]
# # between

# %%
df["total_bill"].between(10,30)
# Out:
# 0      True
# 1      True
# 2      True
# 3      True
# 4      True
#        ...
# 239    True
# 240    True
# 241    True
# 242    True
# 243    True
# Name: total_bill, Length: 244, dtype: bool

# %%
df[df["total_bill"].between(10,20)]
# Out:
#      total_bill   tip sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01   F     No   Sun  Dinner     2              8.49
# 1         10.34  1.66   M     No   Sun  Dinner     3              3.45
# 8         15.04  1.96   M     No   Sun  Dinner     2              7.52
# 9         14.78  3.23   M     No   Sun  Dinner     2              7.39
# 10        10.27  1.71   M     No   Sun  Dinner     2              5.14
# ..          ...   ...  ..    ...   ...     ...   ...               ...
# 234       15.53  3.00   M    Yes   Sat  Dinner     2              7.76
# 235       10.07  1.25   M     No   Sat  Dinner     2              5.04
# 236       12.60  1.00   M    Yes   Sat  Dinner     2              6.30
# 242       17.82  1.75   M     No   Sat  Dinner     2              8.91
# 243       18.78  3.00   F     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410    Sun2959
# ...

# %%
df[df["total_bill"].between(10,20,inclusive=True)]
# Out:
#      total_bill   tip sex smoker   day    time  size  price_per_person  \
# 0         16.99  1.01   F     No   Sun  Dinner     2              8.49
# 1         10.34  1.66   M     No   Sun  Dinner     3              3.45
# 8         15.04  1.96   M     No   Sun  Dinner     2              7.52
# 9         14.78  3.23   M     No   Sun  Dinner     2              7.39
# 10        10.27  1.71   M     No   Sun  Dinner     2              5.14
# ..          ...   ...  ..    ...   ...     ...   ...               ...
# 234       15.53  3.00   M    Yes   Sat  Dinner     2              7.76
# 235       10.07  1.25   M     No   Sat  Dinner     2              5.04
# 236       12.60  1.00   M    Yes   Sat  Dinner     2              6.30
# 242       17.82  1.75   M     No   Sat  Dinner     2              8.91
# 243       18.78  3.00   F     No  Thur  Dinner     2              9.39
#
#              Payer Name         CC Number Payment ID
# 0    Christy Cunningham  3560325168603410    Sun2959
# ...

# %% [markdown]
# # largest

# %%
df.nlargest(2,"total_bill")
# Out:
#      total_bill   tip sex smoker  day    time  size  price_per_person  \
# 170       50.81  10.0   M    Yes  Sat  Dinner     3             16.94
# 212       48.33   9.0   M     No  Sat  Dinner     4             12.08
#
#           Payer Name         CC Number Payment ID
# 170    Gregory Clark  5473850968388236    Sat1954
# 212  Alex Williamson      676218815212    Sat4590

# %%
# take first largest column, and if it same then go to next column
df.nlargest(2,["price_per_person","total_bill"])
# Out:
#      total_bill   tip sex smoker  day    time  size  price_per_person  \
# 184       40.55  3.00   M    Yes  Sun  Dinner     2             20.27
# 179       34.63  3.55   M    Yes  Sun  Dinner     2             17.32
#
#        Payer Name         CC Number Payment ID
# 184   Stephen Cox  3547798222044029    Sun5140
# 179  Brian Bailey   346656312114848    Sun9851

# %%
#similiar to 
df.sort_values("total_bill",ascending=False).iloc[0:2]
# Out:
#      total_bill   tip sex smoker  day    time  size  price_per_person  \
# 170       50.81  10.0   M    Yes  Sat  Dinner     3             16.94
# 212       48.33   9.0   M     No  Sat  Dinner     4             12.08
#
#           Payer Name         CC Number Payment ID
# 170    Gregory Clark  5473850968388236    Sat1954
# 212  Alex Williamson      676218815212    Sat4590

# %%
df.nsmallest(2,["total_bill"])
# Out:
#     total_bill  tip sex smoker  day    time  size  price_per_person  \
# 67        3.07  1.0   F    Yes  Sat  Dinner     1              3.07
# 92        5.75  1.0   F    Yes  Fri  Dinner     2              2.88
#
#        Payer Name         CC Number Payment ID
# 67  Tiffany Brock  4359488526995267    Sat3455
# 92   Leah Ramirez  3508911676966392    Fri3780

# %% [markdown]
# # sample

# %%
df.sample(5)
# Out:
#      total_bill   tip sex smoker   day    time  size  price_per_person  \
# 41        17.46  2.54   M     No   Sun  Dinner     2              8.73
# 169       10.63  2.00   F    Yes   Sat  Dinner     2              5.32
# 89        21.16  3.00   M     No  Thur   Lunch     2             10.58
# 83        32.68  5.00   M    Yes  Thur   Lunch     2             16.34
# 45        18.29  3.00   M     No   Sun  Dinner     2              9.14
#
#              Payer Name         CC Number Payment ID
# 41          David Boyer  3536678244278149    Sun9460
# 169            Amy Hill  3536332481454019    Sat1788
# 89          Keith Lewis  4356005144080422   Thur6273
# 83        Daniel Murphy  5356177501009133   Thur8801
# 45   Richard Fitzgerald   375156610762053    Sun8643

# %%
df.sample(frac=0.1)
# Out:
#      total_bill   tip sex smoker   day    time  size  price_per_person  \
# 234       15.53  3.00   M    Yes   Sat  Dinner     2              7.76
# 171       15.81  3.16   M    Yes   Sat  Dinner     2              7.90
# 212       48.33  9.00   M     No   Sat  Dinner     4             12.08
# 69        15.01  2.09   M    Yes   Sat  Dinner     2              7.50
# 114       25.71  4.00   F     No   Sun  Dinner     3              8.57
# 73        25.28  5.00   F    Yes   Sat  Dinner     2             12.64
# 166       20.76  2.24   M     No   Sun  Dinner     2             10.38
# 95        40.17  4.73   M    Yes   Fri  Dinner     4             10.04
# 148        9.78  1.73   M     No  Thur   Lunch     2              4.89
# 208       24.27  2.03   M    Yes   Sat  Dinner     2             12.14
# 209       12.76  2.23   F    Yes   Sat  Dinner     2              6.38
# 137       14.15  2.00   F     No  Thur   Lunch     2              7.08
# ...
