# %%
import pandas as pd
import numpy as np

# %%
df2=pd.read_csv("../../pythonProject/data_ml/hiring.csv")

# %%
df2.head()
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000

# %%
df2["experience"]
# Out:
# 0       NaN
# 1       NaN
# 2      five
# 3       two
# 4     seven
# 5     three
# 6       ten
# 7    eleven
# Name: experience, dtype: object

# %%
df2[["experience","salary($)"]]
# Out:
#   experience  salary($)
# 0        NaN      50000
# 1        NaN      45000
# 2       five      60000
# 3        two      65000
# 4      seven      70000
# 5      three      62000
# 6        ten      72000
# 7     eleven      80000

# %%
df2["new_col"]=df2["test_score(out of 10)"]+df2["interview_score(out of 10)"]+0.467

# %%
df2
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)  \
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000
#
#    new_col
# 0   17.467
# 1   14.467
# 2   13.467
# 3   20.467
# 4   15.467
# 5   17.467
# 6      NaN
# 7   15.467

# %%
df2["new_col"]=np.round(df2["new_col"],2)

# %%
df2
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)  \
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000
#
#    new_col
# 0    17.47
# 1    14.47
# 2    13.47
# 3    20.47
# 4    15.47
# 5    17.47
# 6      NaN
# 7    15.47

# %%
df2["new_col"]=np.round(df2["new_col"])
df2
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)  \
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000
#
#    new_col
# 0     17.0
# 1     14.0
# 2     13.0
# 3     20.0
# 4     15.0
# 5     17.0
# 6      NaN
# 7     15.0

# %%
newarr=np.random.rand(4,4)

# %%
newarr
# Out:
# array([[0.91339319, 0.20549281, 0.33589248, 0.62052892],
#        [0.98567075, 0.20227951, 0.17343773, 0.02834296],
#        [0.29164478, 0.53294204, 0.74706355, 0.80351554],
#        [0.46626967, 0.90663357, 0.26733763, 0.73369015]])

# %%
newarr=np.round(newarr,2)
newarr
# Out:
# array([[0.91, 0.21, 0.34, 0.62],
#        [0.99, 0.2 , 0.17, 0.03],
#        [0.29, 0.53, 0.75, 0.8 ],
#        [0.47, 0.91, 0.27, 0.73]])

# %%
#by default axis=0 and it search for key
df2.drop("interview_score(out of 10)",axis=1)
# Out:
#   experience  test_score(out of 10)  salary($)  new_col
# 0        NaN                    8.0      50000     17.0
# 1        NaN                    8.0      45000     14.0
# 2       five                    6.0      60000     13.0
# 3        two                   10.0      65000     20.0
# 4      seven                    9.0      70000     15.0
# 5      three                    7.0      62000     17.0
# 6        ten                    NaN      72000      NaN
# 7     eleven                    7.0      80000     15.0

# %%
df2.drop(["experience","new_col"],axis=1)
# Out:
#    test_score(out of 10)  interview_score(out of 10)  salary($)
# 0                    8.0                           9      50000
# 1                    8.0                           6      45000
# 2                    6.0                           7      60000
# 3                   10.0                          10      65000
# 4                    9.0                           6      70000
# 5                    7.0                          10      62000
# 6                    NaN                           7      72000
# 7                    7.0                           8      80000

# %%
df2
# Out:
#   experience  test_score(out of 10)  interview_score(out of 10)  salary($)  \
# 0        NaN                    8.0                           9      50000
# 1        NaN                    8.0                           6      45000
# 2       five                    6.0                           7      60000
# 3        two                   10.0                          10      65000
# 4      seven                    9.0                           6      70000
# 5      three                    7.0                          10      62000
# 6        ten                    NaN                           7      72000
# 7     eleven                    7.0                           8      80000
#
#    new_col
# 0     17.0
# 1     14.0
# 2     13.0
# 3     20.0
# 4     15.0
# 5     17.0
# 6      NaN
# 7     15.0

# %%
df2.drop("interview_score(out of 10)",axis=1)
# Out:
#   experience  test_score(out of 10)  salary($)  new_col
# 0        NaN                    8.0      50000     17.0
# 1        NaN                    8.0      45000     14.0
# 2       five                    6.0      60000     13.0
# 3        two                   10.0      65000     20.0
# 4      seven                    9.0      70000     15.0
# 5      three                    7.0      62000     17.0
# 6        ten                    NaN      72000      NaN
# 7     eleven                    7.0      80000     15.0

# %%
df2.drop("test_score(out of 10)",axis=1,inplace=True)

# %%
df2
# Out:
#   experience  interview_score(out of 10)  salary($)  new_col
# 0        NaN                           9      50000     17.0
# 1        NaN                           6      45000     14.0
# 2       five                           7      60000     13.0
# 3        two                          10      65000     20.0
# 4      seven                           6      70000     15.0
# 5      three                          10      62000     17.0
# 6        ten                           7      72000      NaN
# 7     eleven                           8      80000     15.0

# %% [markdown]
# # Rows

# %%
df3=pd.read_csv("../../pythonProject/data_ml/hiring.csv")
df3["ids"]=["aa","bb","cc","dd","ee","ff","gg","hh"]

# %%
df3=df3.set_index("ids")
df3
# Out:
#     experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# ids
# aa         NaN                    8.0                           9      50000
# bb         NaN                    8.0                           6      45000
# cc        five                    6.0                           7      60000
# dd         two                   10.0                          10      65000
# ee       seven                    9.0                           6      70000
# ff       three                    7.0                          10      62000
# gg         ten                    NaN                           7      72000
# hh      eleven                    7.0                           8      80000

# %%
#access row by default index
df3.iloc[0]
# Out:
# experience                      NaN
# test_score(out of 10)           8.0
# interview_score(out of 10)        9
# salary($)                     50000
# Name: aa, dtype: object

# %%
#access row by key name
df3.loc["cc"]
# Out:
# experience                     five
# test_score(out of 10)           6.0
# interview_score(out of 10)        7
# salary($)                     60000
# Name: cc, dtype: object

# %%
df3.iloc[:3]
# Out:
#     experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# ids
# aa         NaN                    8.0                           9      50000
# bb         NaN                    8.0                           6      45000
# cc        five                    6.0                           7      60000

# %%
#we can use this in place of drop
df4=df3.iloc[1:4]

# %%
df4
# Out:
#     experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# ids
# bb         NaN                    8.0                           6      45000
# cc        five                    6.0                           7      60000
# dd         two                   10.0                          10      65000

# %%
df3.loc[["cc","dd","hh"]]
# Out:
#     experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# ids
# cc        five                    6.0                           7      60000
# dd         two                   10.0                          10      65000
# hh      eleven                    7.0                           8      80000

# %%
#by daefaul 0 so we can use keys
df3.drop("dd")
# Out:
#     experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# ids
# aa         NaN                    8.0                           9      50000
# bb         NaN                    8.0                           6      45000
# cc        five                    6.0                           7      60000
# ee       seven                    9.0                           6      70000
# ff       three                    7.0                          10      62000
# gg         ten                    NaN                           7      72000
# hh      eleven                    7.0                           8      80000

# %%
df3.drop(["dd","ee","hh"])
# Out:
#     experience  test_score(out of 10)  interview_score(out of 10)  salary($)
# ids
# aa         NaN                    8.0                           9      50000
# bb         NaN                    8.0                           6      45000
# cc        five                    6.0                           7      60000
# ff       three                    7.0                          10      62000
# gg         ten                    NaN                           7      72000
