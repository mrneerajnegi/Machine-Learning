# %%
import pandas as pd
import seaborn as sbn
import matplotlib.pyplot as plt
import numpy as np

# %%
df= pd.read_csv("../data/05-Seaborn/dm_office_sales.csv")
df
# Out:
#               division  level of education  training level  work experience  \
# 0             printers        some college               2                6
# 1             printers  associate's degree               2               10
# 2          peripherals         high school               0                9
# 3      office supplies  associate's degree               2                5
# 4      office supplies         high school               1                5
# ..                 ...                 ...             ...              ...
# 995  computer hardware  associate's degree               1                1
# 996  computer software  associate's degree               1                0
# 997        peripherals  associate's degree               2                8
# 998        peripherals  associate's degree               2                3
# 999  computer hardware        some college               0                9
#
#      salary   sales
# 0     91684  372302
# ...

# %%
plt.figure(figsize=(10,4),dpi=200)
sbn.countplot(x="level of education",data=df)
# Out:
# <AxesSubplot:xlabel='level of education', ylabel='count'>

# %%
plt.figure(figsize=(10,4),dpi=200)
sbn.countplot(x="level of education",data=df)
plt.ylim(0,1000)
# Out:
# (0.0, 1000.0)

# %%
plt.figure(figsize=(10,4),dpi=200)
sbn.countplot(x="level of education",data=df,hue="division")
# plt.ylim(0,1000)
plt.legend(loc=(1.1,0.5))

# %%
plt.figure(figsize=(10,4),dpi=200)
sbn.barplot(data=df,x="level of education",y="salary")
# Out:
# <AxesSubplot:xlabel='level of education', ylabel='salary'>

# %%
plt.figure(figsize=(10,4),dpi=200)
sbn.barplot(data=df,x="level of education",y="salary",hue="training level")
plt.legend(loc=(1.1,0.5))

# %%
plt.figure(figsize=(10,4),dpi=200)
sbn.barplot(data=df,x="level of education",y="salary",hue="training level")
plt.legend(loc=(1.1,0.5))

# %%
# we can also aggregate method in barplot, bydefault it is mean
plt.figure(figsize=(10,4),dpi=200)
sbn.barplot(data=df,x="level of education",y="salary",hue="training level",estimator=np.mean)
plt.legend(loc=(1.1,0.5))
