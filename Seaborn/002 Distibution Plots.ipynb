# %% [raw]
# Distribution Plots display single continous feature
# 3 main distibution plot types :
#     -Rug Plot
#     -Histogram
#     -KDE Plot
#
#     Rug Plot. : add a dash or tick line every single value and y axis do not really have a meaning
#
#     Histogram : If we count ticks there are varios x ranges , we can create a Histogram
#
#     KDE : stands for kernel density estimation , it is a method of estimating a probablity density function
#           of a random variable.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn
import numpy as np

# %%
df=pd.read_csv("../data/05-Seaborn/dm_office_sales.csv")
df
# Out:
#               division  level of education  training level  work experience  \
# 0             printers        some college               2                6
# 1             printers  associate's degree               2               10
# 2          peripherals         high school               0                9
# 3      office supplies  associate's degree               2                5
# 4      office supplies         high school               1                5
# ..                 ...                 ...             ...              ...
# 995  computer hardware  associate's degree               1                1
# 996  computer software  associate's degree               1                0
# 997        peripherals  associate's degree               2                8
# 998        peripherals  associate's degree               2                3
# 999  computer hardware        some college               0                9
#
#      salary   sales
# 0     91684  372302
# ...

# %%
sbn.rugplot(x="salary",data=df,height=0.5)
# Out:
# <AxesSubplot:xlabel='salary'>

# %%
#it is more genral way to try to use this if we compare with histplot
sbn.displot(x="salary",data=df,color='orange',bins=10,edgecolor='red')

# %%
sbn.histplot(x="salary",data=df,color='orange',bins=10,edgecolor='red',lw=3)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='Count'>

# %%
#we can use kde and rug plot with displot that is not possible with histplot
sbn.displot(x="salary",data=df,color='orange',bins=10,edgecolor='red',kde=True,rug=True)

# %%
sbn.histplot(x="salary",data=df,color='orange',bins=10,edgecolor='red',kde=true)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-1d876edd9bda> in <module>
# ----> 1 sbn.histplot(x="salary",data=df,color='orange',bins=10,edgecolor='red',kde=true)
#
# NameError: name 'true' is not defined

# %%
sbn.kdeplot(x="salary",data=df)
# Out:
# <AxesSubplot:xlabel='salary', ylabel='Density'>

# %%
np.random.seed(42)
df2=np.random.randint(0,100,200)
df2
# Out:
# array([51, 92, 14, 71, 60, 20, 82, 86, 74, 74, 87, 99, 23,  2, 21, 52,  1,
#        87, 29, 37,  1, 63, 59, 20, 32, 75, 57, 21, 88, 48, 90, 58, 41, 91,
#        59, 79, 14, 61, 61, 46, 61, 50, 54, 63,  2, 50,  6, 20, 72, 38, 17,
#         3, 88, 59, 13,  8, 89, 52,  1, 83, 91, 59, 70, 43,  7, 46, 34, 77,
#        80, 35, 49,  3,  1,  5, 53,  3, 53, 92, 62, 17, 89, 43, 33, 73, 61,
#        99, 13, 94, 47, 14, 71, 77, 86, 61, 39, 84, 79, 81, 52, 23, 25, 88,
#        59, 40, 28, 14, 44, 64, 88, 70,  8, 87,  0,  7, 87, 62, 10, 80,  7,
#        34, 34, 32,  4, 40, 27,  6, 72, 71, 11, 33, 32, 47, 22, 61, 87, 36,
#        98, 43, 85, 90, 34, 64, 98, 46, 77,  2,  0,  4, 89, 13, 26,  8, 78,
#        14, 89, 41, 76, 50, 62, 95, 51, 95,  3, 93, 22, 14, 42, 28, 35, 12,
#        31, 70, 58, 85, 27, 65, 41, 44, 61, 56,  5, 27, 27, 43, 83, 29, 61,
#        74, 91, 88, 61, 96,  0, 26, 61, 76,  2, 69, 71, 26])

# %%
sbn.displot(df2,kde=True)

# %%
sbn.kdeplot(df2)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
#compare both plots, in first one kde is not from 0 so to do this
sbn.kdeplot(df2,clip=[0,100])
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
#bw_adjust => adjust bw_adjust accordingly
sbn.kdeplot(df2,clip=[0,100],bw_adjust=0.6)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sbn.kdeplot(df2,clip=[0,100],bw_adjust=0.1)
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
sbn.kdeplot(df2,clip=[0,100],bw_adjust=5)
# Out:
# <AxesSubplot:ylabel='Density'>
